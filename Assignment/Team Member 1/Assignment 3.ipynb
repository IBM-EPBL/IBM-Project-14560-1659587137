# %% [markdown]
# **BUILDING A REGRESSION MODEL**

# %% [markdown]
# **1. Import Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **2. Load the dataset into the tool**

# %%
data = pd.read_csv('/content/abalone.csv')
data
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# ...              ...           ...    ...
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
data.shape
# Out:
# (4177, 9)

# %%
Age=1.5+data.Rings
data["Age"]=Age
data=data.rename(columns = {'Whole weight':'Whole_weight','Shucked weight': 'Shucked_weight','Viscera weight': 'Viscera_weight',
                            'Shell weight': 'Shell_weight'})
data=data.drop(columns=["Rings"],axis=1)
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5

# %% [markdown]
# **3. PERFORM BELOW VISUALIZATIONS**

# %% [markdown]
# **Univariate Analysis**

# %%
sns.displot(data["Age"], color='darkorange')

# %%
sns.histplot(y=data.Age,color='Green')

# %%
sns.histplot(x=data.Age,color='Blue')

# %% [markdown]
# **Boxplot**

# %%
sns.boxplot(x=data.Age,color='pink')

# %% [markdown]
# **Countplot**

# %%
sns.countplot(x=data.Age)

# %% [markdown]
# **Bi-Variate Analysis**

# %% [markdown]
# **Barplot**

# %%
sns.barplot(x=data.Length,y=data.Age)

# %% [markdown]
# **Linearplot**

# %%
sns.lineplot(x=data.Age,y=data.Height, color='purple')

# %% [markdown]
# **Scatterplot**

# %%
sns.scatterplot(x=data.Age,y=data.Height,color='green')

# %% [markdown]
# **Pointplot**

# %%
sns.pointplot(x=data.Age, y=data.Height, color="blue")

# %% [markdown]
# **Regplot**

# %%
sns.regplot(x=data.Age,y=data.Height,color='orange')

# %% [markdown]
# **Multi-Variate Analysis**

# %%
sns.pairplot(data=data[["Height","Length","Diameter","Age","Whole_weight","Shucked_weight","Viscera_weight","Shell_weight"]])

# %% [markdown]
# **4. Perform Descriptive Statistics on the Dataset**

# %%
data.describe(include='all')
# Out:
#                Sex       Length     Diameter       Height  Whole_weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.179594      0.828742
# std       0.822240     0.120093     0.099240     0.520156      0.490389
# min       0.000000     0.075000     0.055000     0.040000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.145000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     7.000000      2.825500
#
#        Shucked_weight  Viscera_weight  Shell_weight          Age
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831    11.433684
# std          0.221963        0.109614      0.139203     3.224169
# min          0.001000        0.000500      0.001500     2.500000
# 25%          0.186000        0.093500      0.130000     9.500000
# 50%          0.336000        0.171000      0.234000    10.500000
# 75%          0.502000        0.253000      0.329000    12.500000
# max          1.488000        0.760000      1.005000    30.500000

# %% [markdown]
# **5. Check for Missing Values and Deal with them.**

# %%
data.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Age               0
# dtype: int64

# %% [markdown]
# **6. Find the outliers and replace them outliers**

# %%
outlier=data.quantile(q=(0.25,0.75))
outlier
# Out:
#       Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0.25  0.0   0.450      0.35   0.115        0.4415           0.186
# 0.75  2.0   0.615      0.48   0.165        1.1530           0.502
#
#       Viscera_weight  Shell_weight   Age
# 0.25          0.0935         0.130   9.5
# 0.75          0.2530         0.329  12.5

# %%
a = data.Age.quantile(0.25)
b = data.Age.quantile(0.75)
c = b - a
lower_limit = a - 1.5 * c
data.median(numeric_only=True)
# Out:
# Sex                1.0000
# Length             0.5450
# Diameter           0.4250
# Height             0.1450
# Whole_weight       0.7995
# Shucked_weight     0.3360
# Viscera_weight     0.1710
# Shell_weight       0.2340
# Age               10.5000
# dtype: float64

# %%
data['Age'] = np.where(data['Age'] < lower_limit, 7, data['Age'])
sns.boxplot(x=data.Age,showfliers = False)

# %% [markdown]
# **7. Check for Categorical columns and perform
# encoding**

# %% [markdown]
# **Label encoding**

# %%
data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5

# %%
from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()
data.Sex = lab.fit_transform(data.Sex)

data.head()
# Out:
#    Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0    2   0.455     0.365   0.095        0.5140          0.2245
# 1    2   0.350     0.265   0.090        0.2255          0.0995
# 2    0   0.530     0.420   0.135        0.6770          0.2565
# 3    2   0.440     0.365   0.125        0.5160          0.2155
# 4    1   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5

# %% [markdown]
# **8. Split the data into dependent and
# independent variables.**

# %%
p = data.drop(columns=['Sex'],axis = 1)
p.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
y = data["Sex"]
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    1
# Name: Sex, dtype: int64

# %%
q = data.Sex
q.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    1
# Name: Sex, dtype: int64

# %%
x=data.drop(columns=["Sex"],axis=1)
x.head()
# Out:
#    Length  Diameter  Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell_weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %% [markdown]
# **9. Scale the independent variables**

# %%
from sklearn.preprocessing import scale
X_Scaled = pd.DataFrame(scale(x), columns=x.columns)
X_Scaled.head()
# Out:
#      Length  Diameter    Height  Whole_weight  Shucked_weight  Viscera_weight  \
# 0 -0.574558 -0.432149 -0.162652     -0.641898       -0.607685       -0.726212
# 1 -1.448986 -1.439929 -0.172266     -1.230277       -1.170910       -1.205221
# 2  0.050033  0.122130 -0.085743     -0.309469       -0.463500       -0.356690
# 3 -0.699476 -0.432149 -0.104970     -0.637819       -0.648238       -0.607600
# 4 -1.615544 -1.540707 -0.191493     -1.272086       -1.215968       -1.287337
#
#    Shell_weight       Age
# 0     -0.638217  1.577830
# 1     -1.212987 -0.919022
# 2     -0.207139 -0.294809
# 3     -0.602294  0.017298
# 4     -1.320757 -0.919022

# %% [markdown]
# **10. Split the data into training and testing**

# %%
from sklearn.model_selection import train_test_split
X_Train, X_Test, Y_Train, Y_Test = train_test_split(X_Scaled, y, test_size=0.2, random_state=0)

# %%
X_Train.shape,X_Test.shape
# Out:
# ((3341, 8), (836, 8))

# %%
Y_Train.shape,Y_Test.shape
# Out:
# ((3341,), (836,))

# %%
X_Train.head()
# Out:
#         Length  Diameter    Height  Whole_weight  Shucked_weight  \
# 3141 -2.864726 -2.750043 -0.191493     -1.622870       -1.553902
# 3521 -2.573250 -2.598876 -0.239561     -1.606554       -1.551650
# 883   1.132658  1.230689 -0.018447      1.145672        1.041436
# 3627  1.590691  1.180300  0.039235      2.164373        2.661269
# 2106  0.591345  0.474853 -0.047288      0.432887        0.255175
#
#       Viscera_weight  Shell_weight       Age
# 3141       -1.583867     -1.644065 -1.543234
# 3521       -1.565619     -1.626104 -1.387181
# 883         0.286552      1.538726  1.577830
# 3627        2.330326      1.377072  0.017298
# 2106        0.272866      0.906479  1.265723

# %%
X_Test.head()
# Out:
#         Length  Diameter    Height  Whole_weight  Shucked_weight  \
# 668   0.216591  0.172519 -0.047288      0.181016       -0.368878
# 1580 -0.199803 -0.079426 -0.114584     -0.433875       -0.443224
# 3784  0.799543  0.726798 -0.047288      0.870348        0.755318
# 463  -2.531611 -2.447709 -0.239561     -1.579022       -1.522362
# 2615  1.007740  0.928354 -0.008833      1.390405        1.415417
#
#       Viscera_weight  Shell_weight       Age
# 668         0.569396      0.690940  0.953617
# 1580       -0.343004     -0.325685 -0.606915
# 3784        1.764639      0.565209  0.329404
# 463        -1.538247     -1.572219 -1.543234
# 2615        1.778325      0.996287  0.641511

# %%
Y_Train.head()
# Out:
# 3141    1
# 3521    1
# 883     2
# 3627    2
# 2106    2
# Name: Sex, dtype: int64

# %%
Y_Test.head()
# Out:
# 668     2
# 1580    1
# 3784    2
# 463     1
# 2615    2
# Name: Sex, dtype: int64

# %% [markdown]
# **11. Build the Model**

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10,criterion='entropy')

# %%
model.fit(X_Train,Y_Train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_predict = mdl.predict(X_Test)

# %%
y_predict_train = mdl.predict(X_Train)

# %% [markdown]
# **12. Train the Model**

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print('Training accuracy: ',accuracy_score(Y_Train,y_predict_train))
# Out:
# Training accuracy:  0.3205627057767136

# %% [markdown]
# **13.Test the Model**

# %%
print('Testing accuracy: ',accuracy_score(Y_Test,y_predict))
# Out:
# Testing accuracy:  0.3145933014354067

# %% [markdown]
# **14. Measure the performance using Metrics**

# %%
pd.crosstab(Y_Test,y_predict)
# Out:
# col_0   0    1   2
# Sex
# 0      86   82  81
# 1      97   98  96
# 2      97  120  79

# %%
print(classification_report(Y_Test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.35      0.33       249
#            1       0.33      0.34      0.33       291
#            2       0.31      0.27      0.29       296
#
#     accuracy                           0.31       836
#    macro avg       0.31      0.32      0.31       836
# weighted avg       0.31      0.31      0.31       836
